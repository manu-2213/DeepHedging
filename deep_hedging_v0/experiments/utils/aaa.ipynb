# %%
import torch

# %%
module = torch.nn.Sequential(
    torch.nn.Linear(12,12)
)

# %%
optim = torch.optim.Adam(lr=1e-4, params=module.parameters())

# %%
optim.param_groups[0]['lr']
# Out:
# 0.0001
